# %%
import requests
import urllib

querystring = "Mitski"

url = f'https://zylalabs.com/api/94/music+gigs+and+concerts+tracker+api/146/get+concerts+by+artist?name={querystring}?'
print(url)

headers = {
    "Authorization": "Bearer 662|0y9phDoyxwEMPK7u4lwTMgaIj2Sbnj48qAUPRhqw"
    }

response = requests.get(url, headers=headers)

print(response)
# Out:
# https://zylalabs.com/api/94/music+gigs+and+concerts+tracker+api/146/get+concerts+by+artist?name=Mitski
# <Response [200]>

# %%
apikey = 'bH98AS06cMd23p9lqXUHk8cXI8M2ir6M' 
secret = 'KjUOGWGTI9Gbjh1a'
url = f'https://app.ticketmaster.com/discovery/v2/events.json?attractionId=K8vZ917Gku7&countryCode=CA&apikey={apikey}'
try_this = requests.get(url)
print(try_this)
# Out:
# <Response [200]>

# %%
import ticketpy
tm_client = ticketpy.ApiClient('bH98AS06cMd23p9lqXUHk8cXI8M2ir6M')
pages = tm_client.events.find(
    classification_name='Hip-Hop',
    state_code='IL',
    start_date_time='2017-05-19T20:00:00Z',
    end_date_time='2017-05-21T20:00:00Z'
)

for page in pages:
    for event in page:
        print(event)

# %%
# Out:
# Event:            British Royalty: Tributes to The Rolling Stones & David Bowie
# Venues:           [<ticketpy.model.Venue object at 0x000001AF3C728550>]
# Start date:       2023-04-01
# Start time:       20:00:00
# Price ranges:     [{'min': 15.0, 'max': 52.0}]
# Status:           onsale
# Classifications:  [<ticketpy.model.EventClassification object at 0x000001AF3D8D5FD0>, <ticketpy.model.EventClassification object at 0x000001AF3D8D7E50>]

# %%
top_20 = {
  "href": "https://api.spotify.com/v1/me/top/artists",
  "items": [
    {
      "external_urls": {
        "spotify": "https://open.spotify.com/artist/0L8ExT028jH3ddEcZwqJJ5"
      },
      "followers": {
        "href": None,
        "total": 19089416
      },
      "genres": [
        "alternative rock",
        "funk metal",
        "funk rock",
        "permanent wave"
      ],
      "href": "https://api.spotify.com/v1/artists/0L8ExT028jH3ddEcZwqJJ5",
      "id": "0L8ExT028jH3ddEcZwqJJ5",
      "images": [
        {
          "height": 640,
          "url": "https://i.scdn.co/image/ab6761610000e5ebc33cc15260b767ddec982ce8",
          "width": 640
        },
        {
          "height": 320,
          "url": "https://i.scdn.co/image/ab67616100005174c33cc15260b767ddec982ce8",
          "width": 320
        },
        {
          "height": 160,
          "url": "https://i.scdn.co/image/ab6761610000f178c33cc15260b767ddec982ce8",
          "width": 160
        }
      ],
      "name": "Red Hot Chili Peppers",
      "popularity": 84,
      "type": "artist",
      "uri": "spotify:artist:0L8ExT028jH3ddEcZwqJJ5"
    },
    {
      "external_urls": {
        "spotify": "https://open.spotify.com/artist/3WrFJ7ztbogyGnTHbHJFl2"
      },
      "followers": {
        "href": None,
        "total": 24529753
      },
      "genres": [
        "beatlesque",
        "british invasion",
        "classic rock",
        "merseybeat",
        "psychedelic rock",
        "rock"
      ],
      "href": "https://api.spotify.com/v1/artists/3WrFJ7ztbogyGnTHbHJFl2",
      "id": "3WrFJ7ztbogyGnTHbHJFl2",
      "images": [
        {
          "height": 640,
          "url": "https://i.scdn.co/image/ab6761610000e5ebe9348cc01ff5d55971b22433",
          "width": 640
        },
        {
          "height": 320,
          "url": "https://i.scdn.co/image/ab67616100005174e9348cc01ff5d55971b22433",
          "width": 320
        },
        {
          "height": 160,
          "url": "https://i.scdn.co/image/ab6761610000f178e9348cc01ff5d55971b22433",
          "width": 160
        }
      ],
      "name": "The Beatles",
      "popularity": 85,
      "type": "artist",
      "uri": "spotify:artist:3WrFJ7ztbogyGnTHbHJFl2"
    },
    {
      "external_urls": {
        "spotify": "https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ"
      },
      "followers": {
        "href": None,
        "total": 57598314
      },
      "genres": [
        "canadian contemporary r&b",
        "canadian pop",
        "pop"
      ],
      "href": "https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ",
      "id": "1Xyo4u8uXC1ZmMpatF05PJ",
      "images": [
        {
          "height": 640,
          "url": "https://i.scdn.co/image/ab6761610000e5ebb5f9e28219c169fd4b9e8379",
          "width": 640
        },
        {
          "height": 320,
          "url": "https://i.scdn.co/image/ab67616100005174b5f9e28219c169fd4b9e8379",
          "width": 320
        },
        {
          "height": 160,
          "url": "https://i.scdn.co/image/ab6761610000f178b5f9e28219c169fd4b9e8379",
          "width": 160
        }
      ],
      "name": "The Weeknd",
      "popularity": 98,
      "type": "artist",
      "uri": "spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ"
    },
    {
      "external_urls": {
        "spotify": "https://open.spotify.com/artist/0Y6dVaC9DZtPNH4591M42W"
      },
      "followers": {
        "href": None,
        "total": 1662406
      },
      "genres": [
        "indie pop"
      ],
      "href": "https://api.spotify.com/v1/artists/0Y6dVaC9DZtPNH4591M42W",
      "id": "0Y6dVaC9DZtPNH4591M42W",
      "images": [
        {
          "height": 640,
          "url": "https://i.scdn.co/image/ab67616d0000b27332f5fec7a879ed6ef28f0dfd",
          "width": 640
        },
        {
          "height": 300,
          "url": "https://i.scdn.co/image/ab67616d00001e0232f5fec7a879ed6ef28f0dfd",
          "width": 300
        },
        {
          "height": 64,
          "url": "https://i.scdn.co/image/ab67616d0000485132f5fec7a879ed6ef28f0dfd",
          "width": 64
        }
      ],
      "name": "TV Girl",
      "popularity": 77,
      "type": "artist",
      "uri": "spotify:artist:0Y6dVaC9DZtPNH4591M42W"
    },
    {
      "external_urls": {
        "spotify": "https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02"
      },
      "followers": {
        "href": None,
        "total": 66989232
      },
      "genres": [
        "pop"
      ],
      "href": "https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02",
      "id": "06HL4z0CvFAxyc27GXpf02",
      "images": [
        {
          "height": 640,
          "url": "https://i.scdn.co/image/ab6761610000e5eb5a00969a4698c3132a15fbb0",
          "width": 640
        },
        {
          "height": 320,
          "url": "https://i.scdn.co/image/ab676161000051745a00969a4698c3132a15fbb0",
          "width": 320
        },
        {
          "height": 160,
          "url": "https://i.scdn.co/image/ab6761610000f1785a00969a4698c3132a15fbb0",
          "width": 160
        }
      ],
      "name": "Taylor Swift",
      "popularity": 99,
      "type": "artist",
      "uri": "spotify:artist:06HL4z0CvFAxyc27GXpf02"
    },
    {
      "external_urls": {
        "spotify": "https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x"
      },
      "followers": {
        "href": None,
        "total": 19217734
      },
      "genres": [
        "chicago rap",
        "rap"
      ],
      "href": "https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x",
      "id": "5K4W6rqBFWDnAN6FQUkS6x",
      "images": [
        {
          "height": 640,
          "url": "https://i.scdn.co/image/ab6761610000e5eb867008a971fae0f4d913f63a",
          "width": 640
        },
        {
          "height": 320,
          "url": "https://i.scdn.co/image/ab67616100005174867008a971fae0f4d913f63a",
          "width": 320
        },
        {
          "height": 160,
          "url": "https://i.scdn.co/image/ab6761610000f178867008a971fae0f4d913f63a",
          "width": 160
        }
      ],
      "name": "Kanye West",
      "popularity": 92,
      "type": "artist",
      "uri": "spotify:artist:5K4W6rqBFWDnAN6FQUkS6x"
    },
    {
      "external_urls": {
        "spotify": "https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4"
      },
      "followers": {
        "href": None,
        "total": 71463522
      },
      "genres": [
        "canadian hip hop",
        "canadian pop",
        "hip hop",
        "rap",
        "toronto rap"
      ],
      "href": "https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4",
      "id": "3TVXtAsR1Inumwj472S9r4",
      "images": [
        {
          "height": 640,
          "url": "https://i.scdn.co/image/ab6761610000e5eb4293385d324db8558179afd9",
          "width": 640
        },
        {
          "height": 320,
          "url": "https://i.scdn.co/image/ab676161000051744293385d324db8558179afd9",
          "width": 320
        },
        {
          "height": 160,
          "url": "https://i.scdn.co/image/ab6761610000f1784293385d324db8558179afd9",
          "width": 160
        }
      ],
      "name": "Drake",
      "popularity": 98,
      "type": "artist",
      "uri": "spotify:artist:3TVXtAsR1Inumwj472S9r4"
    },
    {
      "external_urls": {
        "spotify": "https://open.spotify.com/artist/0cQbJU1aAzvbEmTuljWLlF"
      },
      "followers": {
        "href": None,
        "total": 2423671
      },
      "genres": [
        "alternative rock",
        "dance pop",
        "dance rock",
        "permanent wave",
        "pop rock"
      ],
      "href": "https://api.spotify.com/v1/artists/0cQbJU1aAzvbEmTuljWLlF",
      "id": "0cQbJU1aAzvbEmTuljWLlF",
      "images": [
        {
          "height": 667,
          "url": "https://i.scdn.co/image/f7e39e0ca7a4ba897150247190fb27b6ae6e0318",
          "width": 1000
        },
        {
          "height": 427,
          "url": "https://i.scdn.co/image/062f558dbf9cd7d8f820a094b84d7c6513c1ef8f",
          "width": 640
        },
        {
          "height": 133,
          "url": "https://i.scdn.co/image/6d74978edc9ec01cec160888e62d986b80aaea51",
          "width": 200
        },
        {
          "height": 43,
          "url": "https://i.scdn.co/image/3877d00cef020004a2b8fcb9d69d85981f0b1f38",
          "width": 64
        }
      ],
      "name": "No Doubt",
      "popularity": 68,
      "type": "artist",
      "uri": "spotify:artist:0cQbJU1aAzvbEmTuljWLlF"
    },
    {
      "external_urls": {
        "spotify": "https://open.spotify.com/artist/4LLpKhyESsyAXpc4laK94U"
      },
      "followers": {
        "href": None,
        "total": 8518594
      },
      "genres": [
        "hip hop",
        "pittsburgh rap",
        "rap"
      ],
      "href": "https://api.spotify.com/v1/artists/4LLpKhyESsyAXpc4laK94U",
      "id": "4LLpKhyESsyAXpc4laK94U",
      "images": [
        {
          "height": 640,
          "url": "https://i.scdn.co/image/ab6761610000e5ebed3b89aa602145fde71a163a",
          "width": 640
        },
        {
          "height": 320,
          "url": "https://i.scdn.co/image/ab67616100005174ed3b89aa602145fde71a163a",
          "width": 320
        },
        {
          "height": 160,
          "url": "https://i.scdn.co/image/ab6761610000f178ed3b89aa602145fde71a163a",
          "width": 160
        }
      ],
      "name": "Mac Miller",
      "popularity": 85,
      "type": "artist",
      "uri": "spotify:artist:4LLpKhyESsyAXpc4laK94U"
    },
    {
      "external_urls": {
        "spotify": "https://open.spotify.com/artist/7DjwIxbe8kpw4pqnzAMoin"
      },
      "followers": {
        "href": None,
        "total": 102113
      },
      "genres": [
        "auckland indie",
        "bubblegrunge",
        "indie pop",
        "indie punk",
        "indie rock",
        "kiwi rock",
        "modern power pop",
        "nz indie"
      ],
      "href": "https://api.spotify.com/v1/artists/7DjwIxbe8kpw4pqnzAMoin",
      "id": "7DjwIxbe8kpw4pqnzAMoin",
      "images": [
        {
          "height": 640,
          "url": "https://i.scdn.co/image/ab6761610000e5eb67a4ee2671abdaa121a8afc2",
          "width": 640
        },
        {
          "height": 320,
          "url": "https://i.scdn.co/image/ab6761610000517467a4ee2671abdaa121a8afc2",
          "width": 320
        },
        {
          "height": 160,
          "url": "https://i.scdn.co/image/ab6761610000f17867a4ee2671abdaa121a8afc2",
          "width": 160
        }
      ],
      "name": "The Beths",
      "popularity": 53,
      "type": "artist",
      "uri": "spotify:artist:7DjwIxbe8kpw4pqnzAMoin"
    },
    {
      "external_urls": {
        "spotify": "https://open.spotify.com/artist/00FQb4jTyendYWaN8pK0wa"
      },
      "followers": {
        "href": None,
        "total": 20602347
      },
      "genres": [
        "art pop",
        "pop"
      ],
      "href": "https://api.spotify.com/v1/artists/00FQb4jTyendYWaN8pK0wa",
      "id": "00FQb4jTyendYWaN8pK0wa",
      "images": [
        {
          "height": 640,
          "url": "https://i.scdn.co/image/ab6761610000e5ebb99cacf8acd5378206767261",
          "width": 640
        },
        {
          "height": 320,
          "url": "https://i.scdn.co/image/ab67616100005174b99cacf8acd5378206767261",
          "width": 320
        },
        {
          "height": 160,
          "url": "https://i.scdn.co/image/ab6761610000f178b99cacf8acd5378206767261",
          "width": 160
        }
      ],
      "name": "Lana Del Rey",
      "popularity": 91,
      "type": "artist",
      "uri": "spotify:artist:00FQb4jTyendYWaN8pK0wa"
    },
    {
      "external_urls": {
        "spotify": "https://open.spotify.com/artist/6CwfuxIqcltXDGjfZsMd9A"
      },
      "followers": {
        "href": None,
        "total": 4328735
      },
      "genres": [
        "dance pop",
        "electropop",
        "metropopolis",
        "pop",
        "uk alternative pop"
      ],
      "href": "https://api.spotify.com/v1/artists/6CwfuxIqcltXDGjfZsMd9A",
      "id": "6CwfuxIqcltXDGjfZsMd9A",
      "images": [
        {
          "height": 640,
          "url": "https://i.scdn.co/image/ab6761610000e5eb951d80a1db6ae486a5ce5f36",
          "width": 640
        },
        {
          "height": 320,
          "url": "https://i.scdn.co/image/ab67616100005174951d80a1db6ae486a5ce5f36",
          "width": 320
        },
        {
          "height": 160,
          "url": "https://i.scdn.co/image/ab6761610000f178951d80a1db6ae486a5ce5f36",
          "width": 160
        }
      ],
      "name": "MARINA",
      "popularity": 75,
      "type": "artist",
      "uri": "spotify:artist:6CwfuxIqcltXDGjfZsMd9A"
    },
    {
      "external_urls": {
        "spotify": "https://open.spotify.com/artist/3zmfs9cQwzJl575W1ZYXeT"
      },
      "followers": {
        "href": None,
        "total": 1066107
      },
      "genres": [
        "indie pop"
      ],
      "href": "https://api.spotify.com/v1/artists/3zmfs9cQwzJl575W1ZYXeT",
      "id": "3zmfs9cQwzJl575W1ZYXeT",
      "images": [
        {
          "height": 640,
          "url": "https://i.scdn.co/image/ab6761610000e5ebfd30ebd7e80dad6b2383aab0",
          "width": 640
        },
        {
          "height": 320,
          "url": "https://i.scdn.co/image/ab67616100005174fd30ebd7e80dad6b2383aab0",
          "width": 320
        },
        {
          "height": 160,
          "url": "https://i.scdn.co/image/ab6761610000f178fd30ebd7e80dad6b2383aab0",
          "width": 160
        }
      ],
      "name": "Men I Trust",
      "popularity": 72,
      "type": "artist",
      "uri": "spotify:artist:3zmfs9cQwzJl575W1ZYXeT"
    },
    {
      "external_urls": {
        "spotify": "https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK"
      },
      "followers": {
        "href": None,
        "total": 4228300
      },
      "genres": [
        "brooklyn indie",
        "indie pop"
      ],
      "href": "https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK",
      "id": "2uYWxilOVlUdk4oV9DvwqK",
      "images": [
        {
          "height": 640,
          "url": "https://i.scdn.co/image/ab6761610000e5ebafb309e27fdb45e093958f9c",
          "width": 640
        },
        {
          "height": 320,
          "url": "https://i.scdn.co/image/ab67616100005174afb309e27fdb45e093958f9c",
          "width": 320
        },
        {
          "height": 160,
          "url": "https://i.scdn.co/image/ab6761610000f178afb309e27fdb45e093958f9c",
          "width": 160
        }
      ],
      "name": "Mitski",
      "popularity": 81,
      "type": "artist",
      "uri": "spotify:artist:2uYWxilOVlUdk4oV9DvwqK"
    },
    {
      "external_urls": {
        "spotify": "https://open.spotify.com/artist/3MATPJ9tYbcMhw5VOZrRU6"
      },
      "followers": {
        "href": None,
        "total": 306345
      },
      "genres": [
        "indie garage rock"
      ],
      "href": "https://api.spotify.com/v1/artists/3MATPJ9tYbcMhw5VOZrRU6",
      "id": "3MATPJ9tYbcMhw5VOZrRU6",
      "images": [
        {
          "height": 640,
          "url": "https://i.scdn.co/image/ab6761610000e5ebf545d72c0579b73a0eb09470",
          "width": 640
        },
        {
          "height": 320,
          "url": "https://i.scdn.co/image/ab67616100005174f545d72c0579b73a0eb09470",
          "width": 320
        },
        {
          "height": 160,
          "url": "https://i.scdn.co/image/ab6761610000f178f545d72c0579b73a0eb09470",
          "width": 160
        }
      ],
      "name": "Summer Salt",
      "popularity": 55,
      "type": "artist",
      "uri": "spotify:artist:3MATPJ9tYbcMhw5VOZrRU6"
    },
    {
      "external_urls": {
        "spotify": "https://open.spotify.com/artist/35l9BRT7MXmM8bv2WDQiyB"
      },
      "followers": {
        "href": None,
        "total": 1580360
      },
      "genres": [
        "bedroom pop",
        "bubblegrunge",
        "indie pop"
      ],
      "href": "https://api.spotify.com/v1/artists/35l9BRT7MXmM8bv2WDQiyB",
      "id": "35l9BRT7MXmM8bv2WDQiyB",
      "images": [
        {
          "height": 640,
          "url": "https://i.scdn.co/image/ab6761610000e5ebc8b4ad8a13f54ee2a5184838",
          "width": 640
        },
        {
          "height": 320,
          "url": "https://i.scdn.co/image/ab67616100005174c8b4ad8a13f54ee2a5184838",
          "width": 320
        },
        {
          "height": 160,
          "url": "https://i.scdn.co/image/ab6761610000f178c8b4ad8a13f54ee2a5184838",
          "width": 160
        }
      ],
      "name": "beabadoobee",
      "popularity": 76,
      "type": "artist",
      "uri": "spotify:artist:35l9BRT7MXmM8bv2WDQiyB"
    },
    {
      "external_urls": {
        "spotify": "https://open.spotify.com/artist/3fMbdgg4jU18AjLCKBhRSm"
      },
      "followers": {
        "href": None,
        "total": 25836639
      },
      "genres": [
        "pop",
        "r&b",
        "soul"
      ],
      "href": "https://api.spotify.com/v1/artists/3fMbdgg4jU18AjLCKBhRSm",
      "id": "3fMbdgg4jU18AjLCKBhRSm",
      "images": [
        {
          "height": 640,
          "url": "https://i.scdn.co/image/ab6761610000e5eb0e08ea2c4d6789fbf5cbe0aa",
          "width": 640
        },
        {
          "height": 320,
          "url": "https://i.scdn.co/image/ab676161000051740e08ea2c4d6789fbf5cbe0aa",
          "width": 320
        },
        {
          "height": 160,
          "url": "https://i.scdn.co/image/ab6761610000f1780e08ea2c4d6789fbf5cbe0aa",
          "width": 160
        }
      ],
      "name": "Michael Jackson",
      "popularity": 84,
      "type": "artist",
      "uri": "spotify:artist:3fMbdgg4jU18AjLCKBhRSm"
    },
    {
      "external_urls": {
        "spotify": "https://open.spotify.com/artist/1QAJqy2dA3ihHBFIHRphZj"
      },
      "followers": {
        "href": None,
        "total": 6094200
      },
      "genres": [
        "ambient pop",
        "dream pop",
        "el paso indie",
        "shoegaze"
      ],
      "href": "https://api.spotify.com/v1/artists/1QAJqy2dA3ihHBFIHRphZj",
      "id": "1QAJqy2dA3ihHBFIHRphZj",
      "images": [
        {
          "height": 640,
          "url": "https://i.scdn.co/image/ab6761610000e5ebfe9c808643258ecd6770aa7d",
          "width": 640
        },
        {
          "height": 320,
          "url": "https://i.scdn.co/image/ab67616100005174fe9c808643258ecd6770aa7d",
          "width": 320
        },
        {
          "height": 160,
          "url": "https://i.scdn.co/image/ab6761610000f178fe9c808643258ecd6770aa7d",
          "width": 160
        }
      ],
      "name": "Cigarettes After Sex",
      "popularity": 83,
      "type": "artist",
      "uri": "spotify:artist:1QAJqy2dA3ihHBFIHRphZj"
    },
    {
      "external_urls": {
        "spotify": "https://open.spotify.com/artist/3nFkdlSjzX9mRTtwJOzDYB"
      },
      "followers": {
        "href": None,
        "total": 7944759
      },
      "genres": [
        "east coast hip hop",
        "hip hop",
        "rap"
      ],
      "href": "https://api.spotify.com/v1/artists/3nFkdlSjzX9mRTtwJOzDYB",
      "id": "3nFkdlSjzX9mRTtwJOzDYB",
      "images": [
        {
          "height": 640,
          "url": "https://i.scdn.co/image/ab6761610000e5ebc75afcd5a9027f60eaebb5e4",
          "width": 640
        },
        {
          "height": 320,
          "url": "https://i.scdn.co/image/ab67616100005174c75afcd5a9027f60eaebb5e4",
          "width": 320
        },
        {
          "height": 160,
          "url": "https://i.scdn.co/image/ab6761610000f178c75afcd5a9027f60eaebb5e4",
          "width": 160
        }
      ],
      "name": "JAY-Z",
      "popularity": 85,
      "type": "artist",
      "uri": "spotify:artist:3nFkdlSjzX9mRTtwJOzDYB"
    },
    {
      "external_urls": {
        "spotify": "https://open.spotify.com/artist/1ybAN3utgdoUL1MUCtH4QM"
      },
      "followers": {
        "href": None,
        "total": 266418
      },
      "genres": [
        "art pop",
        "chillwave",
        "denver indie",
        "indie pop",
        "indie rock",
        "indie surf"
      ],
      "href": "https://api.spotify.com/v1/artists/1ybAN3utgdoUL1MUCtH4QM",
      "id": "1ybAN3utgdoUL1MUCtH4QM",
      "images": [
        {
          "height": 640,
          "url": "https://i.scdn.co/image/ab6761610000e5eb76d9c0cc8e9bb869a2232d2e",
          "width": 640
        },
        {
          "height": 320,
          "url": "https://i.scdn.co/image/ab6761610000517476d9c0cc8e9bb869a2232d2e",
          "width": 320
        },
        {
          "height": 160,
          "url": "https://i.scdn.co/image/ab6761610000f17876d9c0cc8e9bb869a2232d2e",
          "width": 160
        }
      ],
      "name": "Tennis",
      "popularity": 58,
      "type": "artist",
      "uri": "spotify:artist:1ybAN3utgdoUL1MUCtH4QM"
    }
  ],
  "limit": 20,
  "next": "https://api.spotify.com/v1/me/top/artists?limit=20&offset=20",
  "offset": 0,
  "previous": None,
  "total": 50
}

# %%
from time import sleep
l=[]
#TODO gotta have it so it doesn't have random shit, like filter that out
#TODO slow this thing down to aviod rate spike lmao. But take 25 seconds when you sleep lol
for artist in top_20['items']:
    l.append(artist['name'])
    #print(artist['id'])
for artist in l:
    venues = tm_client.events.find(keyword=artist,classification_name='Music',state_code='IL, OH',sort='relevance,asc').one()
    sleep(1)
    for venue in venues:
        
        print(venue)
# Out:
# Event:            Club 90s Presents:the Weeknd Night
# Venues:           [<ticketpy.model.Venue object at 0x000001AF3DECF4D0>]
# Start date:       2023-02-10
# Start time:       21:00:00
# Price ranges:     [{'min': 17.0, 'max': 23.0}]
# Status:           onsale
# Classifications:  [<ticketpy.model.EventClassification object at 0x000001AF3D8DD250>]
#
# Event:            The Taylor Party: Taylor Swift Night 18+ with ID
# Venues:           [<ticketpy.model.Venue object at 0x000001AF3D2FE390>]
# Start date:       2023-02-04
# Start time:       20:00:00
# Price ranges:     [{'min': 25.0, 'max': 25.0}]
# Status:           onsale
# Classifications:  [<ticketpy.model.EventClassification object at 0x000001AF3D2BF9D0>]
#
# Event:            Taylor Swift | The Eras Tour
# Venues:           [<ticketpy.model.Venue object at 0x000001AF3CF23910>]
# Start date:       2023-07-01
# Start time:       18:30:00
# Price ranges:     [{'min': 109.0, 'max': 571.0}]
# Status:           offsale
# Classifications:  [<ticketpy.model.EventClassification object at 0x000001AF3C6A5B50>]
#
# Event:            Taylor Swift | The Eras Tour
# Venues:           [<ticketpy.model.Venue object at 0x000001AF3CF95350>]
# Start date:       2023-06-30
# Start time:       18:30:00
# Price ranges:     [{'min': 99.0, 'max': 561.0}]
# Status:           offsale
# Classifications:  [<ticketpy.model.EventClassification object at 0x000001AF3CF23310>]
#
# Event:            Taylor Swift | The Eras Tour
# Venues:           [<ticketpy.model.Venue object at 0x000001AF3D0AB150>]
# Start date:       2023-06-04
# Start time:       18:30:00
# Price ranges:     [{'min': 49.0, 'max': 561.0}]
# Status:           offsale
# Classifications:  [<ticketpy.model.EventClassification object at 0x000001AF3CF94390>]
#
# Event:            Taylor Swift | The Eras Tour
# Venues:           [<ticketpy.model.Venue object at 0x000001AF3D0AA1D0>]
# Start date:       2023-06-03
# Start time:       18:30:00
# Price ranges:     [{'min': 49.0, 'max': 571.0}]
# Status:           offsale
# Classifications:  [<ticketpy.model.EventClassification object at 0x000001AF3D0A8990>]
#
# Event:            Taylor Swift | The Eras Tour
# Venues:           [<ticketpy.model.Venue object at 0x000001AF3D0ABE10>]
# Start date:       2023-06-02
# Start time:       18:30:00
# Price ranges:     [{'min': 49.0, 'max': 561.0}]
# Status:           offsale
# Classifications:  [<ticketpy.model.EventClassification object at 0x000001AF3D0AB010>]
#
# Event:            The Taylor Party: Taylor Swift Night - 21+
# Venues:           [<ticketpy.model.Venue object at 0x000001AF3D0AA010>]
# Start date:       2023-03-31
# Start time:       20:00:00
# Price ranges:     [{'min': 15.0, 'max': 30.0}]
# Status:           onsale
# Classifications:  [<ticketpy.model.EventClassification object at 0x000001AF3D0AA590>]
#
# Event:            Moth Cock, Swisher, Mark McGuire, Bbob Drake & JGuy
# Venues:           [<ticketpy.model.Venue object at 0x000001AF3CF1F3D0>]
# Start date:       2023-02-17
# Start time:       20:30:00
# Price ranges:     [{'min': 7.0, 'max': 7.0}]
# Status:           onsale
# Classifications:  [<ticketpy.model.EventClassification object at 0x000001AF3DB54A10>, <ticketpy.model.EventClassification object at 0x000001AF3CF20310>, <ticketpy.model.EventClassification object at 0x000001AF3CF23690>, <ticketpy.model.EventClassification object at 0x000001AF3D8EA7D0>]
#
# Event:            Drake White
# Venues:           [<ticketpy.model.Venue object at 0x000001AF3CF1D610>]
# Start date:       2023-04-21
# Start time:       20:00:00
# Price ranges:     [{'min': 23.0, 'max': 23.0}]
# Status:           onsale
# Classifications:  [<ticketpy.model.EventClassification object at 0x000001AF3CF1D950>]
#
# Event:            Drake White
# Venues:           [<ticketpy.model.Venue object at 0x000001AF3D0EFED0>]
# Start date:       2023-04-22
# Start time:       20:00:00
# Price ranges:     [{'min': 23.0, 'max': 23.0}]
# Status:           onsale
# Classifications:  [<ticketpy.model.EventClassification object at 0x000001AF3CF1D090>]
#
# Event:            *SOLD OUT* The Beths with Sidney Gish presented by CHIRP Radio
# Venues:           [<ticketpy.model.Venue object at 0x000001AF3D0EFF10>]
# Start date:       2023-02-25
# Start time:       20:30:00
# Price ranges:     [{'min': 0.0, 'max': 0.0}]
# Status:           onsale
# Classifications:  [<ticketpy.model.EventClassification object at 0x000001AF3D0ECF90>]
#
# Event:            *SOLD OUT* The Beths with Sidney Gish presented by CHIRP Radio
# Venues:           [<ticketpy.model.Venue object at 0x000001AF3D0ED790>]
# Start date:       2023-02-24
# Start time:       20:30:00
# Price ranges:     [{'min': 25.0, 'max': 330.0}]
# Status:           onsale
# Classifications:  [<ticketpy.model.EventClassification object at 0x000001AF3D0EF850>]
#
# Event:            Les Claypools Fearless Flying Frog Brigade - The Summer of Green Tour
# Venues:           [<ticketpy.model.Venue object at 0x000001AF3CFE4810>]
# Start date:       2023-07-02
# Start time:       20:00:00
# Price ranges:     [{'min': 47.5, 'max': 117.5}]
# Status:           offsale
# Classifications:  [<ticketpy.model.EventClassification object at 0x000001AF3CFE4710>]
#
# Event:            Who's Bad: The Ultimate Michael Jackson Experience
# Venues:           [<ticketpy.model.Venue object at 0x000001AF3DA967D0>]
# Start date:       2023-04-15
# Start time:       20:00:00
# Price ranges:     [{'min': 20.0, 'max': 26.0}]
# Status:           rescheduled
# Classifications:  [<ticketpy.model.EventClassification object at 0x000001AF3D0EC950>]
#
# Event:            MJ Live - Michael Jackson Tribute
# Venues:           [<ticketpy.model.Venue object at 0x000001AF3DA97150>]
# Start date:       2023-03-04
# Start time:       19:00:00
# Price ranges:     []
# Status:           onsale
# Classifications:  [<ticketpy.model.EventClassification object at 0x000001AF3DA95510>]

# %%
id = '0x000001AF3C6A5B50'
tm_client.genre_by_id(id)
# Out:
# 2023-02-02 11:18:32,774 - ticketpy.client - ERROR - URL: https://app.ticketmaster.com/discovery/v2/classifications/0x000001AF3C6A5B50?apikey=bH98AS06cMd23p9lqXUHk8cXI8M2ir6M
# Errors: [error(code='DIS1004', detail='Resource not found with provided criteria (locale=*, id=0x000001AF3C6A5B50)', href='/discovery/v2/errors.html#DIS1004')]
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# Cell In[62], line 2
#       1 id = '0x000001AF3C6A5B50'
# ----> 2 tm_client.genre_by_id(id)
#
# File c:\Users\aidan\AppData\Local\Programs\Python\Python311\Lib\site-packages\ticketpy\query.py:177, in ClassificationQuery.genre_by_id(self, genre_id)
#     175 """Return a ``Genre`` matching this ID"""
#     176 genre = None
# --> 177 resp = self.by_id(genre_id)
#     178 if resp.segment:
#     179     for genre in resp.segment.genres:
#
# File c:\Users\aidan\AppData\Local\Programs\Python\Python311\Lib\site-packages\ticketpy\query.py:93, in BaseQuery.by_id(self, entity_id)
#      91 get_url = get_tmpl.format(self.api_client.url, self.method, entity_id)
#      92 r = requests.get(get_url, params=self.api_client.api_key)
# ---> 93 r_json = self.api_client._handle_response(r)
#      94 return self.model.from_json(r_json)
#
# File c:\Users\aidan\AppData\Local\Programs\Python\Python311\Lib\site-packages\ticketpy\client.py:111, in ApiClient._handle_response(self, response)
#     109     self.__error(response)
#     110 else:
# --> 111     self.__unknown_error(response)
#
# File c:\Users\aidan\AppData\Local\Programs\Python\Python311\Lib\site-packages\ticketpy\client.py:150, in ApiClient.__unknown_error(self, response)
#     148     self.__fault(response)
#     149 elif 'errors' in rj:
# --> 150     self.__error(response)
#     151 else:
#     152     raise ApiException(response.status_code, response.text)
#
# File c:\Users\aidan\AppData\Local\Programs\Python\Python311\Lib\site-packages\ticketpy\client.py:128, in ApiClient.__error(response)
#     123 errors = [
#     124     error(err['code'], err['detail'], err['_links']['about']['href'])
#     125     for err in rj['errors']
#     126 ]
#     127 log.error('URL: {}\nErrors: {}'.format(response.url, errors))
# --> 128 raise ApiException(response.status_code, errors, response.url)
#
# ApiException: (404, [error(code='DIS1004', detail='Resource not found with provided criteria (locale=*, id=0x000001AF3C6A5B50)', href='/discovery/v2/errors.html#DIS1004')], 'https://app.ticketmaster.com/discovery/v2/classifications/0x000001AF3C6A5B50?apikey=bH98AS06cMd23p9lqXUHk8cXI8M2ir6M')
